# %%
from steps import exp, Variable, square

# %%
import numpy as np


x = Variable(np.array(0.5))
a = square(x)
b = exp(a)
y = square(b)

y.grad = np.array(1.0)
y.backward()
print(x.grad)
# Out:
# 3.297442541400256

# %%
import numpy as np


x = Variable(np.array(0.5))
y = square(exp(square(x)))

y.grad = np.array(1.0)
y.backward()
print(x.grad)
# Out:
# 3.297442541400256

# %%
import numpy as np


x = Variable(np.array(0.5))
y = square(exp(square(x)))

y.backward()
print(x.grad)
# Out:
# 3.297442541400256

# %%
import numpy as np
x = Variable(np.array(1.0))

# %%
x = Variable(None)

# %%
x = Variable(1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = Variable(1.0)
#
# File ~/github/deeplearning_from_scratch/steps/step09.py:60, in Variable.__init__(self, data)
#      58 if data is not None:
#      59     if not isinstance(data, np.ndarray):
# ---> 60         raise TypeError("{}은(는) 지원하지 않습니다.".format(type(data)))
#      61 self.data = data
#      62 self.grad = None
#
# TypeError: <class 'float'>은(는) 지원하지 않습니다.
