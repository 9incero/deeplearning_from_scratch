# %%
import numpy as np
from dezero import optimizers
import dezero.functions as F
from dezero.models import MLP


np.random.seed(0)
x = np.random.rand(100, 1)
y = np.sin(2 * np.pi * x) + np.random.rand(100, 1)

lr = 0.2
max_iter = 10000
hidden_size = 10

model = MLP((hidden_size, 1))
optimizer = optimizers.MomentumSGD(lr).setup(model)

for i in range(max_iter):
    y_pred = model(x)
    loss = F.mean_squared_error(y, y_pred)

    model.cleargrads()
    loss.backward()

    optimizer.update()
    if i % 1000 == 0:
        print(loss)
# Out:
# variable(0.8165178479901415)
# variable(0.07743134432475612)
# variable(0.07544895098906362)
# variable(0.0746325968784086)
# variable(0.07420983183520882)
# variable(0.07396999906438266)
# variable(0.07383178943164805)
# variable(0.07375198007040336)
# variable(0.07370577899304959)
# variable(0.07367887414821274)
