# %%
from re import X
import numpy as np
from steps import Variable

x = Variable(np.array(2.0))
y = x + np.array(3.0)

print(y)
# Out:
# variable(5.0)

# %%
x = Variable(np.array(2.0))
y = 3.0 * x + 1.0
y
# Out:
# variable(7.0)
