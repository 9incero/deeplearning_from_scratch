# %%
from step01 import Variable
from step02 import Function
import numpy as np


x = Variable(np.array(10))
f = Function()
y = f(x)

print(type(y))
print(y.data)
# Out:
# <class 'step01.Variable'>
# 100

# %%
from step01 import Variable
from step02 import Square
import numpy as np

x = Variable(np.array(10))
f = Square()
y = f(x)

print(type(y))
print(y.data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from step01 import Variable
# ----> 2 from step02 import Square
#       3 import numpy as np
#       5 x = Variable(np.array(10))
#
# ImportError: cannot import name 'Square' from 'step02' (/Users/yoonjae/github/deeplearning_from_scratch/steps/step02.py)
