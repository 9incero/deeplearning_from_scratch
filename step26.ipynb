# %%
import numpy as np
from dezero import Variable
from dezero.utils import get_dot_graph

x0 = Variable(np.array(1.0))
x1 = Variable(np.array(1.0))
y = x0 + x1

x0.name = "x0"
x1.name = "x1"
y.name = "y"

txt = get_dot_graph(y, verbose=False)
print(txt)

with open("sample.dot", "w") as o:
    o.write(txt)

# %%
import numpy as np
from dezero import Variable
from dezero.utils import plot_dot_graph

def goldstein(x, y):
  z  = (1 + (x + y + 1)**2 * (19 - 14*x + 3*x**2 - 14*y + 6*x*y + 3*y**2)) * \
       (30 + (2*x - 3*y)**2 * (18 - 32*x + 12*x**2 + 48*y -36*x*y + 27*y**2))
  return z

x = Variable(np.array(1.0))
y = Variable(np.array(1.0))
z = goldstein(x, y)

z.backward()

x.name = 'x'
y.name = 'y'
z.name = 'z'

plot_dot_graph(z, verbose=False, to_file='goldstein.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 20
#      17 y.name = 'y'
#      18 z.name = 'z'
# ---> 20 plot_dot_graph(z, verbose=False, to_file='goldstein.png')
#
# File ~/github/deeplearning_from_scratch/dezero/utils.py:53, in plot_dot_graph(output, verbose, to_file)
#      50 def plot_dot_graph(output, verbose=True, to_file='graph.png'):
#      51     dot_graph = get_dot_graph(output, verbose)
# ---> 53     tmp_dir = os.path.join(os.path.expandsuer('~'), '.dezero')
#      54     if not os.path.exists(tmp_dir):
#      55         os.mkdir(tmp_dir)
#
# AttributeError: module 'posixpath' has no attribute 'expandsuer'
