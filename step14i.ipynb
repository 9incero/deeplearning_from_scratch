# %%
from steps import Variable, add
import numpy as np

x = Variable(np.array(3.0))
y = add(x, x)
y.backward()
print(x.grad)

x.cleargrad()

y = add(add(x, x), x)
y.backward()
print(x.grad)
# Out:
# 2.0
# 3.0
