# %%
import numpy as np
from steps import Variable, add, square

x = Variable(np.array(2.0))
a = square(x)
y = add(square(a), square(a))
y.backward()

print(y.grad)
print(x.grad)
# Out:
# None
# None
