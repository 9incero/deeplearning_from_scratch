# %%
import numpy as np
from steps import Variable

a = Variable(np.array(3.0))
b = Variable(np.array(2.0))
c = Variable(np.array(1.0))

y = a * b + c
y.backward()

print(y)
print(a.grad)
print(b.grad)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 b = Variable(np.array(2.0))
#       6 c = Variable(np.array(1.0))
# ----> 8 y = a * b + c
#       9 y.backward()
#      11 print(y)
#
# File ~/github/deeplearning_from_scratch/steps/step20.py:105, in Variable.__mul__(self, other)
#     104 def __mul__(self, other):
# --> 105     return mul(self, other)
#
# File ~/github/deeplearning_from_scratch/steps/step20.py:176, in mul(x0, x1)
#     175 def mul(x0, x1):
# --> 176     return Mul()(x0, x1)
#
# TypeError: Mul() missing 1 required positional argument: 'Function'
